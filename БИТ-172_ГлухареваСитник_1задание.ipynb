# %%
import numpy as np
import pandas as pd
s = pd.Series([12,-4,7,9])
s1 = pd.Series([12,-4,7,9], index=['a','b','c','d'])
arr = np.array([1,2,3,4])
s2 = pd.Series(arr)
mydict = {'red': 2000, 'blue': 1000, 'yellow': 500, 'orange': 1000}
myseries = pd.Series(mydict)
frame
data = {'color' : ['blue', 'green', 'yellow', 'red', 'white'],
        'object' : ['ball', 'pen', 'pencil', 'paper', 'mug'],
        'price' : [1.2, 1.0, 0.6, 0.9, 1.7]}
frame = pd.DataFrame(data)
frame2 = pd.DataFrame(data, columns=['object', 'price'])
nestdict = {'red': { 2012: 22, 2013: 33},
            'white': { 2011: 13, 2012: 22, 2013: 16},           
            'blue': { 2011: 17, 2012: 27, 2013: 18}}
frame3 = pd.DataFrame(nestdict)
data = [{"month": 'december', "days": 31}, {"month": 'january', "days": 31}]
frame4 = pd.DataFrame(data)
arr1 = np.array([[1, 2, 3], [11, 22, 33]])
frame5 = pd.DataFrame(arr1)
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-4784a94c-aaae-4f52-9c15-74d36c1c50de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4784a94c-aaae-4f52-9c15-74d36c1c50de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SampleData_Pandas.csv to SampleData_Pandas (1).csv
# User uploaded file "SampleData_Pandas.csv" with length 339291 bytes

# %%
frame6 = pd.read_csv('SampleData_Pandas.csv', delimiter=',')
print(frame6)
# Out:
#                                                                             Дата;Подразделение;Контрагент;Менеджер;Номенклатура;Продажи;Себестоимость;Валовая прибыль
# 01.01.2016;Отдел продаж;Абакус ООО;Петров;Лыжи;... 3051;621983 8983;334914                                             4068.0
# 01.01.2016;Отдел продвижения;Абакус ООО;Сидоров... 153;1289364 407;552584                                              7458.0
# 01.01.2016;Отдел продвижения;Абакус ООО;Сидоров... 373;736779  661;315762                                              7119.0
# 01.01.2016;Отдел продвижения;Абакус ООО;Сидоров... 81356;55859 11017;18619                                            70339.0
# 01.01.2016;Отдел продаж;Билли Боб ООО;Илинская;... 763;1154822 034;494923                                              7288.0
# ...                                                                                                                       ...
# 01.12.2017;Отдел продаж;Эверест ООО;Петров;Проч... 4407;154067 7966;17118                                             64407.0
# 01.12.2017;Отдел продвижения;Яго ООО;Охлобыстин... 15254;15254 23729;1694                                            915254.0
# 01.12.2017;Отдел продвижения;Розничный;Розницов... 23729;9915  254237;5338                                           983051.0
# 01.12.2017;Отдел продвижения;Розничный;Розницов... 254;1083686 441;361228                                              8136.0
# 01.12.2017;Отдел продвижения;Розничный;Розницов... 830508;3050 847458;338                                           9830508.0
#
# [2669 rows x 1 columns]

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': 'Sample upload.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1ERzYQppaFMMPRw62xb_dR9SxYEucIYWj

# %%
downloaded = drive.CreateFile({'id': uploaded.get('id')})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Sample upload file content"
